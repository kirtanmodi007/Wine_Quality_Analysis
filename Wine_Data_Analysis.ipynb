# %% [markdown]
# <h1 align = center> WINE DATA ANALYSIS

# %% [markdown]
# <h3>Belowed picture depicts that which features are actually important while we are analysing WINE DATASET.

# %% [markdown]
# <img src="important_feature.JPG" alt="title" >

# %%
import pandas as pd

# %%
red_df = pd.read_csv("winequality-red.csv")
white_df = pd.read_csv("winequality-white.csv")

# %%
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# <h2> 1. number of samples in Red Wine dataset

# %%
red_df.shape[0]
# Out:
# 1599

# %% [markdown]
# <h2> 2. number of columns in Red Wine dataset

# %%
red_df.shape[1]
# Out:
# 12

# %% [markdown]
# <h2> 3. features with missing values

# %%
for each_column in red_df:
    print(each_column)
    print(red_df[each_column].isna().value_counts())
    print("")
# Out:
# fixed acidity
# False    1599
# Name: fixed acidity, dtype: int64
#
# volatile acidity
# False    1599
# Name: volatile acidity, dtype: int64
#
# citric acid
# False    1599
# Name: citric acid, dtype: int64
#
# residual sugar
# False    1599
# Name: residual sugar, dtype: int64
#
# chlorides
# False    1599
# Name: chlorides, dtype: int64
#
# free sulfur dioxide
# False    1599
# Name: free sulfur dioxide, dtype: int64
#
# total sulfur dioxide
# False    1599
# Name: total sulfur dioxide, dtype: int64
#
# density
# False    1599
# Name: density, dtype: int64
#
# pH
# False    1599
# Name: pH, dtype: int64
#
# sulphates
# False    1599
# Name: sulphates, dtype: int64
#
# alcohol
# False    1599
# Name: alcohol, dtype: int64
#
# quality
# False    1599
# Name: quality, dtype: int64

# %% [markdown]
# <b> So, from the above code execution we can clearly see that there are no NaN value.</b><br>

# %% [markdown]
# <h2> 4. duplicate rows in the Red wine dataset

# %%
len(red_df) - len(red_df.drop_duplicates())
# Out:
# 240

# %% [markdown]
# <h2> 5. number of unique values for quality in each dataset

# %%
red_df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# <h2> 6. mean density of the red wine dataset

# %%
meanDensity = red_df['density'].mean()
print(meanDensity)
# Out:
# 0.9967466791744833

# %% [markdown]
# <h2> Now we want to append both red_df (Red Wine DataFrame) and white_df (White Wine DataFrame) into one dataframe wine_df

# %% [markdown]
# <h4>  <ul>Before appending both datarframe into one dataframe we have to add one extra column in both dataframe which reflects the type of wine.</ul>

# %% [markdown]
# <ul>Inorder to add one column into Particular Dataframe we have to add array of the size of dataframe with Value of that particular wine type..

# %%
import numpy as np

# %%
#This belowed line of code will general a color_red array with RED value repeated for the size of that dataframe.
#In our case there are 1599 rows into red_df dataframe. So, our array will have "red" value for 1599 times.
color_red = np.repeat("red",red_df.shape[0])

# %% [markdown]
# <ul> After making the array we will simply add that array as a New column in red_df dataframe.

# %%
red_df['color'] = color_red

# %%
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# <h3> We will repeat the same process for white_wine_data to add one extra column.

# %%
white_color = np.repeat("white", white_df.shape[0])

# %%
white_df['color'] = white_color

# %%
white_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# <h2> Now we have 1 extra column added into both dataframe. Now we just have to append both the dataframe into one new dataframe. WHich will have combined column of both the dataset.

# %%
wine_df = red_df.append(white_df, ignore_index = True)

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# <h2> So, now we have combined dataset with wine color into one dataframe named wine_df.

# %%
#BY doing this we can remove all the rows from wine_df dataframe.
wine_df = wine_df[0:0]

# %%
wine_df.loc[((wine_df["quality"] > 7) | (wine_df["total sulfur dioxide"] > 10.0)),["total sulfur dioxide"]]
# Out:
#       total sulfur dioxide
# 0                     34.0
# 1                     67.0
# 2                     54.0
# 3                     60.0
# 4                     34.0
# ...                    ...
# 6492                  92.0
# 6493                 168.0
# 6494                 111.0
# 6495                 110.0
# 6496                  98.0
#
# [6433 rows x 1 columns]

# %% [markdown]
# <h1 align=center> Histograms

# %%
hist = wine_df.hist(column = ['fixed acidity'], grid = True)

# %%
hist = wine_df.hist(column = ['total sulfur dioxide'], grid = True)

# %%
hist = wine_df.hist(column = ['pH'], grid = True)

# %%
hist = wine_df.hist(column = ['alcohol'], grid = True)

# %% [markdown]
# <h1 align=center> ScatterPlots

# %%
scatter = wine_df.plot.scatter(x = 'quality', y ='alcohol')

# %%
scatter = wine_df.plot.scatter(x = 'quality', y ='volatile acidity')

# %%
scatter = wine_df.plot.scatter(x = 'quality', y ='pH')

# %%
scatter = wine_df.plot.scatter(x = 'quality', y ='residual sugar')
